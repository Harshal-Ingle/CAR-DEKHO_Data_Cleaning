# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('car_price.csv')
df
# Out:
#       Unnamed: 0                                car_name car_prices_in_rupee  \
# 0              0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1              1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2              2                      Toyota Camry 2.5 G          16.40 Lakh
# 3              3                       Honda Jazz VX CVT           7.77 Lakh
# 4              4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
# ...          ...                                     ...                 ...
# 5507        5507                 BMW X1 sDrive 20d xLine          28.90 Lakh
# 5508        5508                   BMW M Series M4 Coupe          64.90 Lakh
# 5509        5509              Jaguar XF 2.2 Litre Luxury          13.75 Lakh
# 5510        5510                      BMW 7 Series 730Ld          29.90 Lakh
# 5511        5511               BMW 5 Series 520d M Sport          31.90 Lakh
#
# ...

# %%
df.shape[0]
# Out:
# 5512

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5512 non-null   int64
#  1   car_name             5512 non-null   object
#  2   car_prices_in_rupee  5512 non-null   object
#  3   kms_driven           5512 non-null   object
#  4   fuel_type            5512 non-null   object
#  5   transmission         5512 non-null   object
#  6   ownership            5512 non-null   object
#  7   manufacture          5512 non-null   int64
#  8   engine               5512 non-null   object
#  9   Seats                5512 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 430.8+ KB

# %%
df.isnull().sum()
# (df.isnull().sum() / df.shape[0]) * 100 --- To get the percentage null of each column
# Out:
# Unnamed: 0             0
# car_name               0
# car_prices_in_rupee    0
# kms_driven             0
# fuel_type              0
# transmission           0
# ownership              0
# manufacture            0
# engine                 0
# Seats                  0
# dtype: int64

# %%
df.head(1)
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats

# %%
df.dropna(inplace = True)

# %% [markdown]
# # car_name

# %%
# x = df['car_name'][0]
# x.index(" ")               # To find the index number   
# x[:x.index(" ")]

# %%
def company_name(x):
    return x[:x.index(" ")]

# %%
df['company_name'] = df['car_name'].apply(company_name)

# %%
df.head()
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1           1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2           2                      Toyota Camry 2.5 G          16.40 Lakh
# 3           3                       Honda Jazz VX CVT           7.77 Lakh
# 4           4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine  \
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc
# 1  13,248 kms    Petrol    Automatic  1st Owner         2021  1330 cc
# 2  60,343 kms    Petrol    Automatic  1st Owner         2016  2494 cc
# 3  26,696 kms    Petrol    Automatic  1st Owner         2018  1199 cc
# 4  69,414 kms    Petrol       Manual  1st Owner         2016  1199 cc
#
#      Seats company_name
# 0  5 Seats         Jeep
# 1  5 Seats      Renault
# ...

# %%
def car_name(x):
    return x[x.index(" ")+1:]

# %%
df['car_name'] = df['car_name'].apply(car_name)

# %%
df
# Out:
#       Unnamed: 0                           car_name car_prices_in_rupee  \
# 0              0  Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1              1               Duster RXZ Turbo CVT          12.83 Lakh
# 2              2                        Camry 2.5 G          16.40 Lakh
# 3              3                        Jazz VX CVT           7.77 Lakh
# 4              4              Polo 1.2 MPI Highline           5.15 Lakh
# ...          ...                                ...                 ...
# 5507        5507                X1 sDrive 20d xLine          28.90 Lakh
# 5508        5508                  M Series M4 Coupe          64.90 Lakh
# 5509        5509                XF 2.2 Litre Luxury          13.75 Lakh
# 5510        5510                     7 Series 730Ld          29.90 Lakh
# 5511        5511              5 Series 520d M Sport          31.90 Lakh
#
#       kms_driven fuel_type transmission  ownership  manufacture   engine  \
# ...

# %% [markdown]
# # car_prices_in_rupee

# %%
df['car_prices_in_rupee'] = df['car_prices_in_rupee'].str.replace(",","")

# %%
# Problems = 35,000, 38.90 Lakh, 1.02 Crore

# %%
def rupee_change(x):
    p = x.split(" ")
    try:
        if p[1] == 'Lakh':
            return str(round(float(p[0])*100000,1))
        elif p[1] == 'Crore':
            return str(round(float(p[0])*10000000,1))
    except:
            return x

# %%
df['car_prices_in_rupee'] = df['car_prices_in_rupee'].apply(rupee_change)

# %%
df['car_prices_in_rupee'] = df['car_prices_in_rupee'].astype('float64')

# %%
df
# Out:
#       Unnamed: 0                           car_name  car_prices_in_rupee  \
# 0              0  Compass 2.0 Longitude Option BSIV            1003000.0
# 1              1               Duster RXZ Turbo CVT            1283000.0
# 2              2                        Camry 2.5 G            1640000.0
# 3              3                        Jazz VX CVT             777000.0
# 4              4              Polo 1.2 MPI Highline             515000.0
# ...          ...                                ...                  ...
# 5507        5507                X1 sDrive 20d xLine            2890000.0
# 5508        5508                  M Series M4 Coupe            6490000.0
# 5509        5509                XF 2.2 Litre Luxury            1375000.0
# 5510        5510                     7 Series 730Ld            2990000.0
# 5511        5511              5 Series 520d M Sport            3190000.0
#
#      kms_driven fuel_type transmission  ownership  manufacture   engine  \
# ...

# %% [markdown]
# # kms_driven

# %%
df['kms_driven'] = df['kms_driven'].str.replace(",", "")
df['kms_driven'] = df['kms_driven'].str.replace(" kms","")

# %%
df['kms_driven'] = df['kms_driven'].astype("int64")

# %%
df
# Out:
#       Unnamed: 0                           car_name  car_prices_in_rupee  \
# 0              0  Compass 2.0 Longitude Option BSIV            1003000.0
# 1              1               Duster RXZ Turbo CVT            1283000.0
# 2              2                        Camry 2.5 G            1640000.0
# 3              3                        Jazz VX CVT             777000.0
# 4              4              Polo 1.2 MPI Highline             515000.0
# ...          ...                                ...                  ...
# 5507        5507                X1 sDrive 20d xLine            2890000.0
# 5508        5508                  M Series M4 Coupe            6490000.0
# 5509        5509                XF 2.2 Litre Luxury            1375000.0
# 5510        5510                     7 Series 730Ld            2990000.0
# 5511        5511              5 Series 520d M Sport            3190000.0
#
#       kms_driven fuel_type transmission  ownership  manufacture   engine  \
# ...

# %% [markdown]
# # engine

# %%
df['engine'] = df['engine'].str.replace("cc","")

# %%
df['engine'] = df['engine'].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5512 non-null   int64
#  1   car_name             5512 non-null   object
#  2   car_prices_in_rupee  5389 non-null   float64
#  3   kms_driven           5512 non-null   int64
#  4   fuel_type            5512 non-null   object
#  5   transmission         5512 non-null   object
#  6   ownership            5512 non-null   object
#  7   manufacture          5512 non-null   int64
#  8   engine               5512 non-null   int64
#  9   Seats                5512 non-null   object
#  10  company_name         5512 non-null   object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 473.8+ KB

# %% [markdown]
# # Seats

# %%
df['Seats'] = df['Seats'].str.replace(" Seats", "")
df['Seats'] = df['Seats'].astype("int64")

# %%
df
# Out:
#       Unnamed: 0                           car_name  car_prices_in_rupee  \
# 0              0  Compass 2.0 Longitude Option BSIV            1003000.0
# 1              1               Duster RXZ Turbo CVT            1283000.0
# 2              2                        Camry 2.5 G            1640000.0
# 3              3                        Jazz VX CVT             777000.0
# 4              4              Polo 1.2 MPI Highline             515000.0
# ...          ...                                ...                  ...
# 5507        5507                X1 sDrive 20d xLine            2890000.0
# 5508        5508                  M Series M4 Coupe            6490000.0
# 5509        5509                XF 2.2 Litre Luxury            1375000.0
# 5510        5510                     7 Series 730Ld            2990000.0
# 5511        5511              5 Series 520d M Sport            3190000.0
#
#       kms_driven fuel_type transmission  ownership  manufacture  engine  \
# ...

# %%
df.drop(columns ='Unnamed: 0', inplace = True)

# %%
df
# Out:
#                                car_name  car_prices_in_rupee  kms_driven  \
# 0     Compass 2.0 Longitude Option BSIV            1003000.0       86226
# 1                  Duster RXZ Turbo CVT            1283000.0       13248
# 2                           Camry 2.5 G            1640000.0       60343
# 3                           Jazz VX CVT             777000.0       26696
# 4                 Polo 1.2 MPI Highline             515000.0       69414
# ...                                 ...                  ...         ...
# 5507                X1 sDrive 20d xLine            2890000.0       45000
# 5508                  M Series M4 Coupe            6490000.0       29000
# 5509                XF 2.2 Litre Luxury            1375000.0       90000
# 5510                     7 Series 730Ld            2990000.0       79000
# 5511              5 Series 520d M Sport            3190000.0       42000
#
#      fuel_type transmission  ownership  manufacture  engine  Seats  \
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize = (4,3))
sns.boxplot(x = "engine", data = df)
plt.show()
